# %%
import pandas as pd

# %%
import pwd

pwd
# Out:
# <module 'pwd' (built-in)>

# %%
df_drugs = pd.read_csv('wig2/testdata/test.drugs.csv', sep='\t')
df_insurants = pd.read_csv('wig2/testdata/test.insurants.csv', sep='\t')
df_insurance_data = pd.read_csv('wig2/testdata/test.insurance_data.csv', sep='\t')
df_inpatient_cases = pd.read_csv('wig2/testdata/test.inpatient_cases.csv', sep='\t')
df_inpatient_diagnosis = pd.read_csv('wig2/testdata/test.inpatient_diagnosis.csv', sep='\t')
df_inpatient_fees = pd.read_csv('wig2/testdata/test.inpatient_fees.csv', sep='\t')
df_inpatient_procedures = pd.read_csv('wig2/testdata/test.inpatient_procedures.csv', sep='\t')
df_outpatient_cases = pd.read_csv('wig2/testdata/test.outpatient_cases.csv', sep='\t')
df_outpatient_diagnosis = pd.read_csv('wig2/testdata/test.outpatient_diagnosis.csv', sep='\t')
df_outpatient_fees = pd.read_csv('wig2/testdata/test.outpatient_fees.csv', sep='\t')
df_outpatient_procedures = pd.read_csv('wig2/testdata/test.outpatient_procedures.csv', sep='\t')

# %%
def filter_by_timeframe(df, insurance_from_col, insurance_to_col, case_from_col, case_to_col):
    """
    Filters rows from the dataframe where the outpatient/inpatient case timeframe is outside the insurance timeframe.

    Parameters:
        df (pd.DataFrame): The dataframe to filter.
        insurance_from_col (str): Column name for the insurance 'from' date.
        insurance_to_col (str): Column name for the insurance 'to' date.
        case_from_col (str): Column name for the case 'from' date.
        case_to_col (str): Column name for the case 'to' date.

    Returns:
        pd.DataFrame: The filtered dataframe.
    """
    # Ensure columns are datetime for comparison
    df[insurance_from_col] = pd.to_datetime(df[insurance_from_col])
    df[insurance_to_col] = pd.to_datetime(df[insurance_to_col])
    df[case_from_col] = pd.to_datetime(df[case_from_col])
    df[case_to_col] = pd.to_datetime(df[case_to_col])
    
    # Apply filter condition
    filtered_df = df[
        (df[case_from_col] >= df[insurance_from_col]) & 
        (df[case_to_col] <= df[insurance_to_col])
    ]
    return filtered_df

# %%
# Start with `df_insurants` as the base
df_universal = df_insurants
# Incremental joins
df_universal = pd.merge(df_universal, df_insurance_data, on='pid', how='left')

# %% [markdown]
# Insurants-Rows: 1000
# Insurance_Data-Rows: 3818
# After merging both:

# %%
df_universal.shape
# Out:
# (3851, 7)

# %%
# 2 out of 11: insurance, insurance_data
df_universal.rename(columns={"from": "insurance_from", "to": "insurance_to"}, inplace=True)

# %%
df_outpatient_cases.rename(columns={"caseID": "outpatient_caseID","practice code": "outpatient_case_practice_code","from": "outpatient_case_from", 
                                    "to": "outpatient_case_to", "amount due": "outpatient_case_amout_due", "year": "outpatient_case_year",
                                    "quarter": "outpatient_case_quarter"}, inplace=True)
df_outpatient_cases
# Out:
#        pid  outpatient_caseID  outpatient_case_practice_code  \
# 0       72           76264259                    720171600.0
# 1      763           21097556                    823839918.0
# 2      189          166284976                    786077570.0
# 3      782          154749062                    105171228.0
# 4      254          147204667                    514903431.0
# ...    ...                ...                            ...
# 14373  275          156219026                    922806199.0
# 14374   98           70030426                    358043182.0
# 14375  319          159568236                     68123842.0
# 14376  405          197675847                    750434802.0
# 14377  405          112173020                    281519225.0
#
#       outpatient_case_from outpatient_case_to  outpatient_case_amout_due  \
# 0               2020-05-08         2020-05-08                  27.381551
# 1               2020-03-06         2020-03-06                  45.813490
# 2               2018-05-02         2018-06-20                 178.931144
# 3               2020-10-01         2020-12-05                  61.119695
# 4               2019-07-24         2019-07-24                  71.476000
# ...                    ...                ...                        ...
# 14373           2018-10-07         2018-11-30                 135.598197
# 14374           2019-10-24         2019-10-24                  30.537000
# 14375           2019-07-31         2019-07-31                 110.799100
# 14376           2020-03-05         2020-03-05                  39.314367
# 14377           2018-08-23         2018-08-23                  54.814607
#
#        outpatient_case_year  outpatient_case_quarter
# 0                      2020                        2
# 1                      2020                        1
# 2                      2018                        2
# 3                      2020                        4
# 4                      2019                        3
# ...                     ...                      ...
# 14373                  2018                        4
# 14374                  2019                        4
# 14375                  2019                        3
# 14376                  2020                        1
# 14377                  2018                        3
#
# [14378 rows x 8 columns]

# %%
# 3 out of 11: insurance, insurance_data, outpatient_cases
df_universal = pd.merge(df_universal, df_outpatient_cases, on='pid', how='left')

# %%
df_universal.shape
# Out:
# (54814, 14)

# %%
# Show the result of the cartesian product
df_universal.loc[df_universal['pid'] == 1]
# Out:
#    pid  Year of birth  gender insurance_from insurance_to  death  \
# 0    1           1995       1     2020-11-01   2020-12-31    0.0
# 1    1           1995       1     2020-01-01   2020-10-31    0.0
# 2    1           1995       1     2019-01-01   2019-12-31    0.0
# 3    1           1995       1     2018-01-01   2018-12-31    0.0
#
#    regional_code  outpatient_caseID  outpatient_case_practice_code  \
# 0           16.0          4908567.0                    658930651.0
# 1           16.0          4908567.0                    658930651.0
# 2           16.0          4908567.0                    658930651.0
# 3           16.0          4908567.0                    658930651.0
#
#   outpatient_case_from outpatient_case_to  outpatient_case_amout_due  \
# 0           2018-09-13         2018-09-13                  30.075665
# 1           2018-09-13         2018-09-13                  30.075665
# 2           2018-09-13         2018-09-13                  30.075665
# 3           2018-09-13         2018-09-13                  30.075665
#
#    outpatient_case_year  outpatient_case_quarter
# 0                2018.0                      3.0
# 1                2018.0                      3.0
# 2                2018.0                      3.0
# 3                2018.0                      3.0

# %%
df_universal = filter_by_timeframe(
    df_universal,
    insurance_from_col="insurance_from",
    insurance_to_col="insurance_to",
    case_from_col="outpatient_case_from",
    case_to_col="outpatient_case_to"
)

# Check the filtered dataframe
print(df_universal.shape)
# Out:
# (14159, 14)

# %%
df_universal.loc[df_universal['pid'] == 1]
# Out:
#    pid  Year of birth  gender insurance_from insurance_to  death  \
# 3    1           1995       1     2018-01-01   2018-12-31    0.0
#
#    regional_code  outpatient_caseID  outpatient_case_practice_code  \
# 3           16.0          4908567.0                    658930651.0
#
#   outpatient_case_from outpatient_case_to  outpatient_case_amout_due  \
# 3           2018-09-13         2018-09-13                  30.075665
#
#    outpatient_case_year  outpatient_case_quarter
# 3                2018.0                      3.0

# %%
df_outpatient_fees = pd.read_csv('wig2/testdata/test.outpatient_fees.csv', sep='\t')
df_outpatient_fees.rename(columns={"caseID": "outpatient_caseID","physican code": "outpatient_fees_physician_code", "specialty code": "outpatient_fees_specialty_code",
                                   "billing code": "outpatient_fees_billing_code", "quantity": "outpatient_fees_quantity", "date": "outpatient_fees_date"}, inplace=True)
df_outpatient_fees
# Out:
#        pid  outpatient_caseID  outpatient_fees_physician_code  \
# 0       63             374239                     337800201.0
# 1       63             374239                     337800201.0
# 2       63             374239                     337800201.0
# 3       63             374239                     337800201.0
# 4       63             374239                     337800201.0
# ...    ...                ...                             ...
# 68298  172         1052546836                             NaN
# 68299  172         1052546836                             NaN
# 68300  172         1052546836                             NaN
# 68301  172         1052546836                             NaN
# 68302  172         1052546836                             NaN
#
#        outpatient_fees_specialty_code outpatient_fees_billing_code  \
# 0                                 1.0                        03061
# 1                                 1.0                        32001
# 2                                 1.0                        03040
# 3                                 1.0                        03230
# 4                                 1.0                        03060
# ...                               ...                          ...
# 68298                             NaN                        H0000
# 68299                             NaN                        H0000
# 68300                             NaN                          HP2
# 68301                             NaN                          HP3
# 68302                             NaN                        H0000
#
#        outpatient_fees_quantity outpatient_fees_date
# 0                           1.0           2019-09-21
# 1                           1.0           2019-09-21
# 2                           1.0           2019-09-21
# 3                           1.0           2019-09-21
# 4                           1.0           2019-09-21
# ...                         ...                  ...
# 68298                       1.0           2018-09-22
# 68299                       1.0           2018-07-07
# 68300                       1.0           2018-07-06
# 68301                       1.0           2018-07-06
# 68302                       1.0           2018-07-06
#
# [68303 rows x 7 columns]

# %%
# 4 out of 11: insurance, insurance_data, outpatient_cases, outpatient_fees
df_universal = pd.merge(df_universal, df_outpatient_fees, on=['pid', 'outpatient_caseID'], how='left')

# %%
df_universal
# Out:
#         pid  Year of birth  gender insurance_from insurance_to  death  \
# 0         1           1995       1     2018-01-01   2018-12-31    0.0
# 1         1           1995       1     2018-01-01   2018-12-31    0.0
# 2         1           1995       1     2018-01-01   2018-12-31    0.0
# 3         1           1995       1     2018-01-01   2018-12-31    0.0
# 4         1           1995       1     2018-01-01   2018-12-31    0.0
# ...     ...            ...     ...            ...          ...    ...
# 67221  1000           1970       1     2020-01-01   2020-12-31    0.0
# 67222  1000           1970       1     2020-01-01   2020-12-31    0.0
# 67223  1000           1970       1     2020-01-01   2020-12-31    0.0
# 67224  1000           1970       1     2020-01-01   2020-12-31    0.0
# 67225  1000           1970       1     2020-01-01   2020-12-31    0.0
#
#        regional_code  outpatient_caseID  outpatient_case_practice_code  \
# 0               16.0          4908567.0                    658930651.0
# 1               16.0          4908567.0                    658930651.0
# 2               16.0          4908567.0                    658930651.0
# 3               16.0          4908567.0                    658930651.0
# 4               16.0          4908567.0                    658930651.0
# ...              ...                ...                            ...
# 67221            8.0         13347761.0                     58209611.0
# 67222            8.0         13347761.0                     58209611.0
# 67223            8.0         13347761.0                     58209611.0
# 67224            8.0         13347761.0                     58209611.0
# 67225            8.0         13347761.0                     58209611.0
#
#       outpatient_case_from outpatient_case_to  outpatient_case_amout_due  \
# 0               2018-09-13         2018-09-13                  30.075665
# 1               2018-09-13         2018-09-13                  30.075665
# 2               2018-09-13         2018-09-13                  30.075665
# 3               2018-09-13         2018-09-13                  30.075665
# 4               2018-09-13         2018-09-13                  30.075665
# ...                    ...                ...                        ...
# 67221           2020-11-08         2020-11-08                  47.837807
# 67222           2020-11-08         2020-11-08                  47.837807
# 67223           2020-11-08         2020-11-08                  47.837807
# 67224           2020-11-08         2020-11-08                  47.837807
# 67225           2020-11-08         2020-11-08                  47.837807
#
#        outpatient_case_year  outpatient_case_quarter  \
# 0                    2018.0                      3.0
# 1                    2018.0                      3.0
# 2                    2018.0                      3.0
# 3                    2018.0                      3.0
# 4                    2018.0                      3.0
# ...                     ...                      ...
# 67221                2020.0                      4.0
# 67222                2020.0                      4.0
# 67223                2020.0                      4.0
# 67224                2020.0                      4.0
# 67225                2020.0                      4.0
#
#        outpatient_fees_physician_code  outpatient_fees_specialty_code  \
# 0                         610229105.0                             5.0
# 1                         610229105.0                             5.0
# 2                         610229105.0                             5.0
# 3                         610229105.0                             5.0
# 4                         610229105.0                             5.0
# ...                               ...                             ...
# 67221                     636052610.0                            10.0
# 67222                     636052610.0                            10.0
# 67223                     636052610.0                            10.0
# 67224                     636052610.0                            10.0
# 67225                     636052610.0                            10.0
#
#       outpatient_fees_billing_code  outpatient_fees_quantity  \
# 0                            06222                       1.0
# 1                            06220                       1.0
# 2                           06225E                       1.0
# 3                           06220T                       1.0
# 4                           06225T                       1.0
# ...                            ...                       ...
# 67221                        18220                       1.0
# 67222                        32001                       1.0
# 67223                        18222                       1.0
# 67224                        30201                       1.0
# 67225                        18211                       1.0
#
#       outpatient_fees_date
# 0               2018-09-13
# 1               2018-09-13
# 2               2018-09-13
# 3               2018-09-13
# 4               2018-09-13
# ...                    ...
# 67221           2020-11-08
# 67222           2020-11-08
# 67223           2020-11-08
# 67224           2020-11-08
# 67225           2020-11-08
#
# [67226 rows x 19 columns]

# %%
df_outpatient_fees.loc[df_outpatient_fees['pid'] == 1]
# Out:
#        pid  outpatient_caseID  outpatient_fees_physician_code  \
# 38058    1            4908567                     610229105.0
# 38059    1            4908567                     610229105.0
# 38060    1            4908567                     610229105.0
# 38061    1            4908567                     610229105.0
# 38062    1            4908567                     610229105.0
#
#        outpatient_fees_specialty_code outpatient_fees_billing_code  \
# 38058                             5.0                        06222
# 38059                             5.0                        06220
# 38060                             5.0                       06225E
# 38061                             5.0                       06220T
# 38062                             5.0                       06225T
#
#        outpatient_fees_quantity outpatient_fees_date
# 38058                       1.0           2018-09-13
# 38059                       1.0           2018-09-13
# 38060                       1.0           2018-09-13
# 38061                       1.0           2018-09-13
# 38062                       1.0           2018-09-13

# %%
df_universal.loc[df_universal['pid'] == 1]
# Out:
#    pid  Year of birth  gender insurance_from insurance_to  death  \
# 0    1           1995       1     2018-01-01   2018-12-31    0.0
# 1    1           1995       1     2018-01-01   2018-12-31    0.0
# 2    1           1995       1     2018-01-01   2018-12-31    0.0
# 3    1           1995       1     2018-01-01   2018-12-31    0.0
# 4    1           1995       1     2018-01-01   2018-12-31    0.0
#
#    regional_code  outpatient_caseID  outpatient_case_practice_code  \
# 0           16.0          4908567.0                    658930651.0
# 1           16.0          4908567.0                    658930651.0
# 2           16.0          4908567.0                    658930651.0
# 3           16.0          4908567.0                    658930651.0
# 4           16.0          4908567.0                    658930651.0
#
#   outpatient_case_from outpatient_case_to  outpatient_case_amout_due  \
# 0           2018-09-13         2018-09-13                  30.075665
# 1           2018-09-13         2018-09-13                  30.075665
# 2           2018-09-13         2018-09-13                  30.075665
# 3           2018-09-13         2018-09-13                  30.075665
# 4           2018-09-13         2018-09-13                  30.075665
#
#    outpatient_case_year  outpatient_case_quarter  \
# 0                2018.0                      3.0
# 1                2018.0                      3.0
# 2                2018.0                      3.0
# 3                2018.0                      3.0
# 4                2018.0                      3.0
#
#    outpatient_fees_physician_code  outpatient_fees_specialty_code  \
# 0                     610229105.0                             5.0
# 1                     610229105.0                             5.0
# 2                     610229105.0                             5.0
# 3                     610229105.0                             5.0
# 4                     610229105.0                             5.0
#
#   outpatient_fees_billing_code  outpatient_fees_quantity outpatient_fees_date
# 0                        06222                       1.0           2018-09-13
# 1                        06220                       1.0           2018-09-13
# 2                       06225E                       1.0           2018-09-13
# 3                       06220T                       1.0           2018-09-13
# 4                       06225T                       1.0           2018-09-13

# %%
df_outpatient_procedures = pd.read_csv('wig2/testdata/test.outpatient_procedures.csv', sep='\t')
df_outpatient_procedures.rename(columns={"caseID": "outpatient_caseID", "procedure code": "outpatient_procedure_code", "localisation": "outpatient_procedure_localisation",
                                         "date of procedure": "outpatient_procedure_date"}, inplace=True)
df_outpatient_procedures
# Out:
#      pid  outpatient_caseID outpatient_procedure_code  \
# 0    527             288793                   5-142.2
# 1    527             288793                   5-142.2
# 2    551            3765687                   5-156.9
# 3    393            4108489                  5-385.70
# 4    232            4654625                   1-650.2
# ..   ...                ...                       ...
# 114  551          200377624                   5-156.9
# 115  551          200377624                   5-156.9
# 116  551          200804681                   5-156.9
# 117  351          202453658                  5-780.6w
# 118   76          209530248                   5-224.4
#
#      outpatient_procedure_localisation outpatient_procedure_date
# 0                                  1.0                2021-07-19
# 1                                  2.0                2021-07-19
# 2                                  2.0                2020-10-21
# 3                                  1.0                2020-02-16
# 4                                  NaN                2020-01-05
# ..                                 ...                       ...
# 114                                1.0                2021-06-14
# 115                                2.0                2021-06-14
# 116                                2.0                2020-02-10
# 117                                2.0                2020-10-06
# 118                                3.0                2021-01-20
#
# [119 rows x 5 columns]

# %%
df_outpatient_procedures.loc[df_outpatient_procedures['pid'] == 527]
# Out:
#    pid  outpatient_caseID outpatient_procedure_code  \
# 0  527             288793                   5-142.2
# 1  527             288793                   5-142.2
#
#    outpatient_procedure_localisation outpatient_procedure_date
# 0                                1.0                2021-07-19
# 1                                2.0                2021-07-19

# %%
# 5 out of 11: insurance, insurance_data, outpatient_cases, outpatient_fees, outpatient_procedure
df_universal = pd.merge(df_universal, df_outpatient_procedures, on=['pid', 'outpatient_caseID'], how='left')
df_universal
# Out:
#         pid  Year of birth  gender insurance_from insurance_to  death  \
# 0         1           1995       1     2018-01-01   2018-12-31    0.0
# 1         1           1995       1     2018-01-01   2018-12-31    0.0
# 2         1           1995       1     2018-01-01   2018-12-31    0.0
# 3         1           1995       1     2018-01-01   2018-12-31    0.0
# 4         1           1995       1     2018-01-01   2018-12-31    0.0
# ...     ...            ...     ...            ...          ...    ...
# 67314  1000           1970       1     2020-01-01   2020-12-31    0.0
# 67315  1000           1970       1     2020-01-01   2020-12-31    0.0
# 67316  1000           1970       1     2020-01-01   2020-12-31    0.0
# 67317  1000           1970       1     2020-01-01   2020-12-31    0.0
# 67318  1000           1970       1     2020-01-01   2020-12-31    0.0
#
#        regional_code  outpatient_caseID  outpatient_case_practice_code  \
# 0               16.0          4908567.0                    658930651.0
# 1               16.0          4908567.0                    658930651.0
# 2               16.0          4908567.0                    658930651.0
# 3               16.0          4908567.0                    658930651.0
# 4               16.0          4908567.0                    658930651.0
# ...              ...                ...                            ...
# 67314            8.0         13347761.0                     58209611.0
# 67315            8.0         13347761.0                     58209611.0
# 67316            8.0         13347761.0                     58209611.0
# 67317            8.0         13347761.0                     58209611.0
# 67318            8.0         13347761.0                     58209611.0
#
#       outpatient_case_from  ... outpatient_case_year  outpatient_case_quarter  \
# 0               2018-09-13  ...               2018.0                      3.0
# 1               2018-09-13  ...               2018.0                      3.0
# 2               2018-09-13  ...               2018.0                      3.0
# 3               2018-09-13  ...               2018.0                      3.0
# 4               2018-09-13  ...               2018.0                      3.0
# ...                    ...  ...                  ...                      ...
# 67314           2020-11-08  ...               2020.0                      4.0
# 67315           2020-11-08  ...               2020.0                      4.0
# 67316           2020-11-08  ...               2020.0                      4.0
# 67317           2020-11-08  ...               2020.0                      4.0
# 67318           2020-11-08  ...               2020.0                      4.0
#
#        outpatient_fees_physician_code  outpatient_fees_specialty_code  \
# 0                         610229105.0                             5.0
# 1                         610229105.0                             5.0
# 2                         610229105.0                             5.0
# 3                         610229105.0                             5.0
# 4                         610229105.0                             5.0
# ...                               ...                             ...
# 67314                     636052610.0                            10.0
# 67315                     636052610.0                            10.0
# 67316                     636052610.0                            10.0
# 67317                     636052610.0                            10.0
# 67318                     636052610.0                            10.0
#
#        outpatient_fees_billing_code  outpatient_fees_quantity  \
# 0                             06222                       1.0
# 1                             06220                       1.0
# 2                            06225E                       1.0
# 3                            06220T                       1.0
# 4                            06225T                       1.0
# ...                             ...                       ...
# 67314                         18220                       1.0
# 67315                         32001                       1.0
# 67316                         18222                       1.0
# 67317                         30201                       1.0
# 67318                         18211                       1.0
#
#       outpatient_fees_date  outpatient_procedure_code  \
# 0               2018-09-13                        NaN
# 1               2018-09-13                        NaN
# 2               2018-09-13                        NaN
# 3               2018-09-13                        NaN
# 4               2018-09-13                        NaN
# ...                    ...                        ...
# 67314           2020-11-08                        NaN
# 67315           2020-11-08                        NaN
# 67316           2020-11-08                        NaN
# 67317           2020-11-08                        NaN
# 67318           2020-11-08                        NaN
#
#       outpatient_procedure_localisation outpatient_procedure_date
# 0                                   NaN                       NaN
# 1                                   NaN                       NaN
# 2                                   NaN                       NaN
# 3                                   NaN                       NaN
# 4                                   NaN                       NaN
# ...                                 ...                       ...
# 67314                               NaN                       NaN
# 67315                               NaN                       NaN
# 67316                               NaN                       NaN
# 67317                               NaN                       NaN
# 67318                               NaN                       NaN
#
# [67319 rows x 22 columns]

# %%
# Example for insurant with pid= 527 we already have 160 rows
df_universal.loc[df_universal['pid'] == 527]
# Out:
#        pid  Year of birth  gender insurance_from insurance_to  death  \
# 35824  527           1944       1     2018-01-01   2018-12-31    0.0
# 35825  527           1944       1     2018-01-01   2018-12-31    0.0
# 35826  527           1944       1     2018-01-01   2018-12-31    0.0
# 35827  527           1944       1     2018-01-01   2018-12-31    0.0
# 35828  527           1944       1     2018-01-01   2018-12-31    0.0
# ...    ...            ...     ...            ...          ...    ...
# 35969  527           1944       1     2019-01-01   2019-12-31    0.0
# 35970  527           1944       1     2019-01-01   2019-12-31    0.0
# 35971  527           1944       1     2019-01-01   2019-12-31    0.0
# 35972  527           1944       1     2019-01-01   2019-12-31    0.0
# 35973  527           1944       1     2019-01-01   2019-12-31    0.0
#
#        regional_code  outpatient_caseID  outpatient_case_practice_code  \
# 35824           14.0         50626975.0                    843745567.0
# 35825           14.0         50626975.0                    843745567.0
# 35826           14.0         50626975.0                    843745567.0
# 35827           14.0         50626975.0                    843745567.0
# 35828           14.0         50626975.0                    843745567.0
# ...              ...                ...                            ...
# 35969           14.0        169078112.0                    830095166.0
# 35970           14.0        169078112.0                    830095166.0
# 35971           14.0        169078112.0                    830095166.0
# 35972           14.0        169078112.0                    830095166.0
# 35973           14.0        169078112.0                    830095166.0
#
#       outpatient_case_from  ... outpatient_case_year  outpatient_case_quarter  \
# 35824           2018-04-01  ...               2018.0                      2.0
# 35825           2018-04-01  ...               2018.0                      2.0
# 35826           2018-04-01  ...               2018.0                      2.0
# 35827           2018-04-01  ...               2018.0                      2.0
# 35828           2018-04-01  ...               2018.0                      2.0
# ...                    ...  ...                  ...                      ...
# 35969           2019-09-26  ...               2019.0                      3.0
# 35970           2019-09-26  ...               2019.0                      3.0
# 35971           2019-09-26  ...               2019.0                      3.0
# 35972           2019-09-26  ...               2019.0                      3.0
# 35973           2019-09-26  ...               2019.0                      3.0
#
#        outpatient_fees_physician_code  outpatient_fees_specialty_code  \
# 35824                     248584703.0                             3.0
# 35825                     248584703.0                             3.0
# 35826                     248584703.0                             3.0
# 35827                     248584703.0                             3.0
# 35828                     248584703.0                             3.0
# ...                               ...                             ...
# 35969                     264712410.0                            10.0
# 35970                     264712410.0                            10.0
# 35971                     264712410.0                            10.0
# 35972                     264712410.0                            10.0
# 35973                     264712410.0                            10.0
#
#        outpatient_fees_billing_code  outpatient_fees_quantity  \
# 35824                         03230                       1.0
# 35825                         03230                       1.0
# 35826                         03362                       1.0
# 35827                         03221                       1.0
# 35828                         03230                       1.0
# ...                             ...                       ...
# 35969                        30420A                       1.0
# 35970                         30201                       1.0
# 35971                         18227                       1.0
# 35972                         18212                       1.0
# 35973                         32001                       1.0
#
#       outpatient_fees_date  outpatient_procedure_code  \
# 35824           2018-05-09                        NaN
# 35825           2018-04-25                        NaN
# 35826           2018-04-25                        NaN
# 35827           2018-04-25                        NaN
# 35828           2018-04-01                        NaN
# ...                    ...                        ...
# 35969           2019-09-26                        NaN
# 35970           2019-09-26                        NaN
# 35971           2019-09-26                        NaN
# 35972           2019-09-26                        NaN
# 35973           2019-09-26                        NaN
#
#       outpatient_procedure_localisation outpatient_procedure_date
# 35824                               NaN                       NaN
# 35825                               NaN                       NaN
# 35826                               NaN                       NaN
# 35827                               NaN                       NaN
# 35828                               NaN                       NaN
# ...                                 ...                       ...
# 35969                               NaN                       NaN
# 35970                               NaN                       NaN
# 35971                               NaN                       NaN
# 35972                               NaN                       NaN
# 35973                               NaN                       NaN
#
# [150 rows x 22 columns]

# %%
df_outpatient_diagnosis = pd.read_csv('wig2/testdata/test.outpatient_diagnosis.csv', sep='\t')
df_outpatient_diagnosis.rename(columns={"caseID": "outpatient_caseID", "diagnosis": "outpatient_diagnosis", "qualification": "outpatient_diagnosis_qualification",
                                "localisation": "outpatient_diagnosis_localisation"}, inplace=True)

# %%
# Check example diagnosis of insurant with pid=1
df_outpatient_diagnosis.loc[df_outpatient_diagnosis['pid'] == 1]
# Out:
#       pid  outpatient_caseID outpatient_diagnosis  \
# 7208    1            4908567                 M350
# 7209    1            4908567                 H522
# 7210    1            4908567                 H521
# 7211    1            4908567                 H311
# 7212    1            4908567                 H193
# 7213    1            4908567                 H041
#
#      outpatient_diagnosis_qualification  outpatient_diagnosis_localisation
# 7208                                  G                                3.0
# 7209                                  G                                3.0
# 7210                                  G                                3.0
# 7211                                  G                                3.0
# 7212                                  G                                NaN
# 7213                                  G                                3.0

# %%
# 6 out of 11: insurance, insurance_data, outpatient_cases, outpatient_fees, outpatient_procedure, outpatient_diagnosis
df_universal_6 = pd.merge(df_universal, df_outpatient_diagnosis, on=['pid', 'outpatient_caseID'], how='left')
df_universal_6
# Out:
#          pid  Year of birth  gender insurance_from insurance_to  death  \
# 0          1           1995       1     2018-01-01   2018-12-31    0.0
# 1          1           1995       1     2018-01-01   2018-12-31    0.0
# 2          1           1995       1     2018-01-01   2018-12-31    0.0
# 3          1           1995       1     2018-01-01   2018-12-31    0.0
# 4          1           1995       1     2018-01-01   2018-12-31    0.0
# ...      ...            ...     ...            ...          ...    ...
# 417755  1000           1970       1     2020-01-01   2020-12-31    0.0
# 417756  1000           1970       1     2020-01-01   2020-12-31    0.0
# 417757  1000           1970       1     2020-01-01   2020-12-31    0.0
# 417758  1000           1970       1     2020-01-01   2020-12-31    0.0
# 417759  1000           1970       1     2020-01-01   2020-12-31    0.0
#
#         regional_code  outpatient_caseID  outpatient_case_practice_code  \
# 0                16.0          4908567.0                    658930651.0
# 1                16.0          4908567.0                    658930651.0
# 2                16.0          4908567.0                    658930651.0
# 3                16.0          4908567.0                    658930651.0
# 4                16.0          4908567.0                    658930651.0
# ...               ...                ...                            ...
# 417755            8.0         13347761.0                     58209611.0
# 417756            8.0         13347761.0                     58209611.0
# 417757            8.0         13347761.0                     58209611.0
# 417758            8.0         13347761.0                     58209611.0
# 417759            8.0         13347761.0                     58209611.0
#
#        outpatient_case_from  ... outpatient_fees_specialty_code  \
# 0                2018-09-13  ...                            5.0
# 1                2018-09-13  ...                            5.0
# 2                2018-09-13  ...                            5.0
# 3                2018-09-13  ...                            5.0
# 4                2018-09-13  ...                            5.0
# ...                     ...  ...                            ...
# 417755           2020-11-08  ...                           10.0
# 417756           2020-11-08  ...                           10.0
# 417757           2020-11-08  ...                           10.0
# 417758           2020-11-08  ...                           10.0
# 417759           2020-11-08  ...                           10.0
#
#         outpatient_fees_billing_code  outpatient_fees_quantity  \
# 0                              06222                       1.0
# 1                              06222                       1.0
# 2                              06222                       1.0
# 3                              06222                       1.0
# 4                              06222                       1.0
# ...                              ...                       ...
# 417755                         18211                       1.0
# 417756                         18211                       1.0
# 417757                         18211                       1.0
# 417758                         18211                       1.0
# 417759                         18211                       1.0
#
#         outpatient_fees_date  outpatient_procedure_code  \
# 0                 2018-09-13                        NaN
# 1                 2018-09-13                        NaN
# 2                 2018-09-13                        NaN
# 3                 2018-09-13                        NaN
# 4                 2018-09-13                        NaN
# ...                      ...                        ...
# 417755            2020-11-08                        NaN
# 417756            2020-11-08                        NaN
# 417757            2020-11-08                        NaN
# 417758            2020-11-08                        NaN
# 417759            2020-11-08                        NaN
#
#         outpatient_procedure_localisation outpatient_procedure_date  \
# 0                                     NaN                       NaN
# 1                                     NaN                       NaN
# 2                                     NaN                       NaN
# 3                                     NaN                       NaN
# 4                                     NaN                       NaN
# ...                                   ...                       ...
# 417755                                NaN                       NaN
# 417756                                NaN                       NaN
# 417757                                NaN                       NaN
# 417758                                NaN                       NaN
# 417759                                NaN                       NaN
#
#         outpatient_diagnosis outpatient_diagnosis_qualification  \
# 0                       M350                                  G
# 1                       H522                                  G
# 2                       H521                                  G
# 3                       H311                                  G
# 4                       H193                                  G
# ...                      ...                                ...
# 417755                  Q667                                  G
# 417756                 M9983                                  G
# 417757                  M773                                  G
# 417758                 M5416                                  G
# 417759                  M181                                  G
#
#        outpatient_diagnosis_localisation
# 0                                    3.0
# 1                                    3.0
# 2                                    3.0
# 3                                    3.0
# 4                                    NaN
# ...                                  ...
# 417755                               3.0
# 417756                               NaN
# 417757                               3.0
# 417758                               NaN
# 417759                               3.0
#
# [417760 rows x 25 columns]

# %%
# Example for insurant with pid= 527 we already have 1022 rows, after joining 6 tables
df_universal_6.loc[df_universal_6['pid'] == 527]
# Out:
#         pid  Year of birth  gender insurance_from insurance_to  death  \
# 221100  527           1944       1     2018-01-01   2018-12-31    0.0
# 221101  527           1944       1     2018-01-01   2018-12-31    0.0
# 221102  527           1944       1     2018-01-01   2018-12-31    0.0
# 221103  527           1944       1     2018-01-01   2018-12-31    0.0
# 221104  527           1944       1     2018-01-01   2018-12-31    0.0
# ...     ...            ...     ...            ...          ...    ...
# 222117  527           1944       1     2019-01-01   2019-12-31    0.0
# 222118  527           1944       1     2019-01-01   2019-12-31    0.0
# 222119  527           1944       1     2019-01-01   2019-12-31    0.0
# 222120  527           1944       1     2019-01-01   2019-12-31    0.0
# 222121  527           1944       1     2019-01-01   2019-12-31    0.0
#
#         regional_code  outpatient_caseID  outpatient_case_practice_code  \
# 221100           14.0         50626975.0                    843745567.0
# 221101           14.0         50626975.0                    843745567.0
# 221102           14.0         50626975.0                    843745567.0
# 221103           14.0         50626975.0                    843745567.0
# 221104           14.0         50626975.0                    843745567.0
# ...               ...                ...                            ...
# 222117           14.0        169078112.0                    830095166.0
# 222118           14.0        169078112.0                    830095166.0
# 222119           14.0        169078112.0                    830095166.0
# 222120           14.0        169078112.0                    830095166.0
# 222121           14.0        169078112.0                    830095166.0
#
#        outpatient_case_from  ... outpatient_fees_specialty_code  \
# 221100           2018-04-01  ...                            3.0
# 221101           2018-04-01  ...                            3.0
# 221102           2018-04-01  ...                            3.0
# 221103           2018-04-01  ...                            3.0
# 221104           2018-04-01  ...                            3.0
# ...                     ...  ...                            ...
# 222117           2019-09-26  ...                           10.0
# 222118           2019-09-26  ...                           10.0
# 222119           2019-09-26  ...                           10.0
# 222120           2019-09-26  ...                           10.0
# 222121           2019-09-26  ...                           10.0
#
#         outpatient_fees_billing_code  outpatient_fees_quantity  \
# 221100                         03230                       1.0
# 221101                         03230                       1.0
# 221102                         03230                       1.0
# 221103                         03230                       1.0
# 221104                         03230                       1.0
# ...                              ...                       ...
# 222117                         32001                       1.0
# 222118                         32001                       1.0
# 222119                         32001                       1.0
# 222120                         32001                       1.0
# 222121                         32001                       1.0
#
#         outpatient_fees_date  outpatient_procedure_code  \
# 221100            2018-05-09                        NaN
# 221101            2018-05-09                        NaN
# 221102            2018-05-09                        NaN
# 221103            2018-05-09                        NaN
# 221104            2018-05-09                        NaN
# ...                      ...                        ...
# 222117            2019-09-26                        NaN
# 222118            2019-09-26                        NaN
# 222119            2019-09-26                        NaN
# 222120            2019-09-26                        NaN
# 222121            2019-09-26                        NaN
#
#         outpatient_procedure_localisation outpatient_procedure_date  \
# 221100                                NaN                       NaN
# 221101                                NaN                       NaN
# 221102                                NaN                       NaN
# 221103                                NaN                       NaN
# 221104                                NaN                       NaN
# ...                                   ...                       ...
# 222117                                NaN                       NaN
# 222118                                NaN                       NaN
# 222119                                NaN                       NaN
# 222120                                NaN                       NaN
# 222121                                NaN                       NaN
#
#         outpatient_diagnosis outpatient_diagnosis_qualification  \
# 221100                  Z907                                  G
# 221101                 U5000                                  G
# 221102                   R54                                  G
# 221103                  M939                                  G
# 221104                 M8199                                  G
# ...                      ...                                ...
# 222117                 M4292                                  G
# 222118                 M4212                                  G
# 222119                 M0608                                  G
# 222120                  L930                                  G
# 222121                  I839                                  G
#
#        outpatient_diagnosis_localisation
# 221100                               NaN
# 221101                               NaN
# 221102                               NaN
# 221103                               NaN
# 221104                               NaN
# ...                                  ...
# 222117                               NaN
# 222118                               NaN
# 222119                               NaN
# 222120                               NaN
# 222121                               NaN
#
# [1022 rows x 25 columns]

# %%
df_universal_6.to_csv("df_outpatient_6.csv", sep=',', index=True, encoding='utf-8')

# %%
df_universal = pd.merge(df_universal, df_outpatient_diagnosis, on=['pid', 'caseID'], how='left')

df_universal = pd.merge(df_universal, df_inpatient_cases, on='pid', how='left')
df_universal = pd.merge(df_universal, df_inpatient_diagnosis, on=['pid', 'caseID'], how='left')
df_universal = pd.merge(df_universal, df_inpatient_fees, on=['pid', 'caseID'], how='left')
df_universal = pd.merge(df_universal, df_inpatient_procedures, on=['pid', 'caseID'], how='left')
df_universal = pd.merge(df_universal, df_drugs, on='pid', how='left')

# %%
a = df_outpatient_procedures['pid'].unique()
print(sorted(a))
# Out:
# [np.int64(10), np.int64(12), np.int64(15), np.int64(66), np.int64(76), np.int64(84), np.int64(88), np.int64(90), np.int64(91), np.int64(96), np.int64(112), np.int64(115), np.int64(128), np.int64(135), np.int64(166), np.int64(179), np.int64(194), np.int64(227), np.int64(232), np.int64(239), np.int64(261), np.int64(268), np.int64(315), np.int64(316), np.int64(320), np.int64(322), np.int64(327), np.int64(328), np.int64(330), np.int64(338), np.int64(351), np.int64(353), np.int64(390), np.int64(393), np.int64(396), np.int64(399), np.int64(412), np.int64(420), np.int64(428), np.int64(483), np.int64(517), np.int64(519), np.int64(521), np.int64(527), np.int64(541), np.int64(548), np.int64(551), np.int64(575), np.int64(586), np.int64(592), np.int64(596), np.int64(597), np.int64(634), np.int64(635), np.int64(648), np.int64(675), np.int64(696), np.int64(697), np.int64(716), np.int64(719), np.int64(731), np.int64(763), np.int64(776), np.int64(779), np.int64(807), np.int64(809), np.int64(842), np.int64(846), np.int64(901), np.int64(915), np.int64(916), np.int64(946), np.int64(955), np.int64(983), np.int64(988)]

# %%
df_drugs
# Out:
#       pid date of prescription date of dispense  pharma central number  \
# 0     542           2020-04-24       2020-04-26                6444040
# 1      35           2019-06-21       2019-06-23                3507952
# 2     590           2020-11-27       2020-11-27                3507952
# 3     345           2020-02-01       2020-02-02                2754708
# 4     345           2020-04-19       2020-04-23                2754708
# ...   ...                  ...              ...                    ...
# 9394  384           2018-12-15       2018-12-20                4596863
# 9395  814           2018-12-14       2018-12-20                4596863
# 9396  581           2018-04-07       2018-04-07                4596863
# 9397  581           2018-07-08       2018-07-18                4596863
# 9398  581           2018-10-18       2018-10-24                4596863
#
#       specialty of prescriber  physican code  practice code  quantity  \
# 0                        52.0     11441752.0    462545519.0       2.0
# 1                        15.0    100231815.0    118275942.0       1.0
# 2                         1.0     86391701.0    675905294.0       1.0
# 3                         1.0    650812501.0    861471675.0       1.0
# 4                         1.0    650812501.0    861471675.0       1.0
# ...                       ...            ...            ...       ...
# 9394                      0.0    621898700.0     14632358.0       1.0
# 9395                     31.0    768128631.0    794650148.0       1.0
# 9396                      1.0    363816801.0    893595739.0       1.0
# 9397                      1.0    363816801.0    893595739.0       1.0
# 9398                      1.0    363816801.0    893595739.0       1.0
#
#       amount due      atc     ddd
# 0          28.30  N02BB02   8.333
# 1          16.27  N02BB02  16.667
# 2          16.27  N02BB02  16.667
# 3          14.54  H03AA01  50.000
# 4          14.54  H03AA01  50.000
# ...          ...      ...     ...
# 9394       31.56  P01BA02  30.039
# 9395       31.56  P01BA02  30.039
# 9396       31.56  P01BA02  30.039
# 9397       31.56  P01BA02  30.039
# 9398       31.56  P01BA02  30.039
#
# [9399 rows x 11 columns]

# %%
df_drugs = df_drugs.add_prefix('drugs_')
df_drugs.columns = df_drugs.columns.str.replace(' ', '_')

# %%
df_drugs
# Out:
#       drugs_pid drugs_date_of_prescription drugs_date_of_dispense  \
# 0           542                 2020-04-24             2020-04-26
# 1            35                 2019-06-21             2019-06-23
# 2           590                 2020-11-27             2020-11-27
# 3           345                 2020-02-01             2020-02-02
# 4           345                 2020-04-19             2020-04-23
# ...         ...                        ...                    ...
# 9394        384                 2018-12-15             2018-12-20
# 9395        814                 2018-12-14             2018-12-20
# 9396        581                 2018-04-07             2018-04-07
# 9397        581                 2018-07-08             2018-07-18
# 9398        581                 2018-10-18             2018-10-24
#
#       drugs_pharma_central_number  drugs_specialty_of_prescriber  \
# 0                         6444040                           52.0
# 1                         3507952                           15.0
# 2                         3507952                            1.0
# 3                         2754708                            1.0
# 4                         2754708                            1.0
# ...                           ...                            ...
# 9394                      4596863                            0.0
# 9395                      4596863                           31.0
# 9396                      4596863                            1.0
# 9397                      4596863                            1.0
# 9398                      4596863                            1.0
#
#       drugs_physican_code  drugs_practice_code  drugs_quantity  \
# 0              11441752.0          462545519.0             2.0
# 1             100231815.0          118275942.0             1.0
# 2              86391701.0          675905294.0             1.0
# 3             650812501.0          861471675.0             1.0
# 4             650812501.0          861471675.0             1.0
# ...                   ...                  ...             ...
# 9394          621898700.0           14632358.0             1.0
# 9395          768128631.0          794650148.0             1.0
# 9396          363816801.0          893595739.0             1.0
# 9397          363816801.0          893595739.0             1.0
# 9398          363816801.0          893595739.0             1.0
#
#       drugs_amount_due drugs_atc  drugs_ddd
# 0                28.30   N02BB02      8.333
# 1                16.27   N02BB02     16.667
# 2                16.27   N02BB02     16.667
# 3                14.54   H03AA01     50.000
# 4                14.54   H03AA01     50.000
# ...                ...       ...        ...
# 9394             31.56   P01BA02     30.039
# 9395             31.56   P01BA02     30.039
# 9396             31.56   P01BA02     30.039
# 9397             31.56   P01BA02     30.039
# 9398             31.56   P01BA02     30.039
#
# [9399 rows x 11 columns]

# %%
# 7 out of 11: insurance, insurance_data, outpatient_cases, outpatient_fees, outpatient_procedure, outpatient_diagnosis, drugs
df_universal_7 = pd.merge(df_universal_6, df_drugs, left_on='pid', right_on='drugs_pid', how='left')
df_universal_7
# Out:
#           pid  Year of birth  gender insurance_from insurance_to  death  \
# 0           1           1995       1     2018-01-01   2018-12-31    0.0
# 1           1           1995       1     2018-01-01   2018-12-31    0.0
# 2           1           1995       1     2018-01-01   2018-12-31    0.0
# 3           1           1995       1     2018-01-01   2018-12-31    0.0
# 4           1           1995       1     2018-01-01   2018-12-31    0.0
# ...       ...            ...     ...            ...          ...    ...
# 6352857  1000           1970       1     2020-01-01   2020-12-31    0.0
# 6352858  1000           1970       1     2020-01-01   2020-12-31    0.0
# 6352859  1000           1970       1     2020-01-01   2020-12-31    0.0
# 6352860  1000           1970       1     2020-01-01   2020-12-31    0.0
# 6352861  1000           1970       1     2020-01-01   2020-12-31    0.0
#
#          regional_code  outpatient_caseID  outpatient_case_practice_code  \
# 0                 16.0          4908567.0                    658930651.0
# 1                 16.0          4908567.0                    658930651.0
# 2                 16.0          4908567.0                    658930651.0
# 3                 16.0          4908567.0                    658930651.0
# 4                 16.0          4908567.0                    658930651.0
# ...                ...                ...                            ...
# 6352857            8.0         13347761.0                     58209611.0
# 6352858            8.0         13347761.0                     58209611.0
# 6352859            8.0         13347761.0                     58209611.0
# 6352860            8.0         13347761.0                     58209611.0
# 6352861            8.0         13347761.0                     58209611.0
#
#         outpatient_case_from  ... drugs_date_of_prescription  \
# 0                 2018-09-13  ...                 2020-12-13
# 1                 2018-09-13  ...                 2020-12-13
# 2                 2018-09-13  ...                 2020-12-13
# 3                 2018-09-13  ...                 2020-12-13
# 4                 2018-09-13  ...                 2020-12-13
# ...                      ...  ...                        ...
# 6352857           2020-11-08  ...                 2020-10-29
# 6352858           2020-11-08  ...                 2019-12-07
# 6352859           2020-11-08  ...                 2019-07-17
# 6352860           2020-11-08  ...                 2018-06-03
# 6352861           2020-11-08  ...                 2020-11-08
#
#          drugs_date_of_dispense  drugs_pharma_central_number  \
# 0                    2020-12-14                    7387887.0
# 1                    2020-12-14                    7387887.0
# 2                    2020-12-14                    7387887.0
# 3                    2020-12-14                    7387887.0
# 4                    2020-12-14                    7387887.0
# ...                         ...                          ...
# 6352857              2020-11-05                    6912972.0
# 6352858              2019-12-07                    6912972.0
# 6352859              2019-07-18                   11368832.0
# 6352860              2018-06-03                     938982.0
# 6352861              2020-11-08                     262467.0
#
#          drugs_specialty_of_prescriber  drugs_physican_code  \
# 0                                  1.0          999393101.0
# 1                                  1.0          999393101.0
# 2                                  1.0          999393101.0
# 3                                  1.0          999393101.0
# 4                                  1.0          999393101.0
# ...                                ...                  ...
# 6352857                            1.0          102554301.0
# 6352858                            1.0          102554301.0
# 6352859                           15.0          147522015.0
# 6352860                            3.0          194276003.0
# 6352861                           10.0          636052610.0
#
#          drugs_practice_code drugs_quantity  drugs_amount_due drugs_atc  \
# 0                793529553.0            1.0             12.42   N02BB02
# 1                793529553.0            1.0             12.42   N02BB02
# 2                793529553.0            1.0             12.42   N02BB02
# 3                793529553.0            1.0             12.42   N02BB02
# 4                793529553.0            1.0             12.42   N02BB02
# ...                      ...            ...               ...       ...
# 6352857          176657311.0            1.0             16.96   H03AA01
# 6352858          176657311.0            1.0             16.96   H03AA01
# 6352859          408591171.0            1.0             12.76   A02BC02
# 6352860          817162924.0            1.0             12.03   A02BC02
# 6352861           58209611.0            1.0             13.14   N02BB02
#
#         drugs_ddd
# 0           3.333
# 1           3.333
# 2           3.333
# 3           3.333
# 4           3.333
# ...           ...
# 6352857   116.667
# 6352858   116.667
# 6352859    28.000
# 6352860    14.000
# 6352861     5.000
#
# [6352862 rows x 36 columns]

# %%
df_inpatient_cases = pd.read_csv('wig2/testdata/test.inpatient_cases.csv', sep='\t')
df_inpatient_cases = df_inpatient_cases.add_prefix('inpatient_case_')
df_inpatient_cases.columns = df_inpatient_cases.columns.str.replace(' ', '_')
df_inpatient_cases.rename(columns={"inpatient_case_caseID": "inpatient_caseID"}, inplace=True)
df_inpatient_cases
# Out:
#      inpatient_case_pid  inpatient_caseID inpatient_case_date_of_admission  \
# 0                     6           5556089                       2019-06-14
# 1                     6           1568766                       2019-08-30
# 2                     6           2714453                       2019-03-30
# 3                     6            364774                       2018-10-27
# 4                     6          11633323                       2018-07-06
# ..                  ...               ...                              ...
# 721                 986           9750153                       2019-11-21
# 722                 986           9117719                       2019-10-25
# 723                 987           6300871                       2019-01-10
# 724                 995            370981                       2018-12-29
# 725                 995           1564166                       2020-07-23
#
#     inpatient_case_date_of_discharge  inpatient_case_cause_of_admission  \
# 0                         2019-06-14                                NaN
# 1                         2019-08-30                                NaN
# 2                         2019-03-30                                NaN
# 3                         2018-10-27                                NaN
# 4                         2018-07-07                              101.0
# ..                               ...                                ...
# 721                       2019-11-21                                NaN
# 722                       2019-10-26                              107.0
# 723                       2019-01-13                              101.0
# 724                       2018-12-29                                NaN
# 725                       2020-08-21                              101.0
#
#      inpatient_case_cause_of_discharge  inpatient_case_outpatient_treatment  \
# 0                                  NaN                                    1
# 1                                  NaN                                    1
# 2                                  NaN                                    1
# 3                                  NaN                                    1
# 4                                  6.0                                    0
# ..                                 ...                                  ...
# 721                                NaN                                    1
# 722                                1.0                                    0
# 723                                1.0                                    0
# 724                                NaN                                    1
# 725                                1.0                                    0
#
#      inpatient_case_department_admission  inpatient_case_department_discharge
# 0                                    NaN                                  NaN
# 1                                    NaN                                  NaN
# 2                                    NaN                                  NaN
# 3                                    NaN                                  NaN
# 4                                  100.0                                100.0
# ..                                   ...                                  ...
# 721                                  NaN                                  NaN
# 722                                100.0                                100.0
# 723                               3400.0                               3400.0
# 724                                  NaN                                  NaN
# 725                               2900.0                               2900.0
#
# [726 rows x 9 columns]

# %%
# 8 out of 11: insurance, insurance_data, outpatient_cases, outpatient_fees, outpatient_procedure, outpatient_diagnosis, drugs, inpatient_case
df_universal_8 = pd.merge(df_universal_7, df_inpatient_cases, left_on='pid', right_on='inpatient_case_pid', how='left')
df_universal_8
# Out:
#            pid  Year of birth  gender insurance_from insurance_to  death  \
# 0            1           1995       1     2018-01-01   2018-12-31    0.0
# 1            1           1995       1     2018-01-01   2018-12-31    0.0
# 2            1           1995       1     2018-01-01   2018-12-31    0.0
# 3            1           1995       1     2018-01-01   2018-12-31    0.0
# 4            1           1995       1     2018-01-01   2018-12-31    0.0
# ...        ...            ...     ...            ...          ...    ...
# 18080870  1000           1970       1     2020-01-01   2020-12-31    0.0
# 18080871  1000           1970       1     2020-01-01   2020-12-31    0.0
# 18080872  1000           1970       1     2020-01-01   2020-12-31    0.0
# 18080873  1000           1970       1     2020-01-01   2020-12-31    0.0
# 18080874  1000           1970       1     2020-01-01   2020-12-31    0.0
#
#           regional_code  outpatient_caseID  outpatient_case_practice_code  \
# 0                  16.0          4908567.0                    658930651.0
# 1                  16.0          4908567.0                    658930651.0
# 2                  16.0          4908567.0                    658930651.0
# 3                  16.0          4908567.0                    658930651.0
# 4                  16.0          4908567.0                    658930651.0
# ...                 ...                ...                            ...
# 18080870            8.0         13347761.0                     58209611.0
# 18080871            8.0         13347761.0                     58209611.0
# 18080872            8.0         13347761.0                     58209611.0
# 18080873            8.0         13347761.0                     58209611.0
# 18080874            8.0         13347761.0                     58209611.0
#
#          outpatient_case_from  ... drugs_ddd  inpatient_case_pid  \
# 0                  2018-09-13  ...     3.333                 NaN
# 1                  2018-09-13  ...     3.333                 NaN
# 2                  2018-09-13  ...     3.333                 NaN
# 3                  2018-09-13  ...     3.333                 NaN
# 4                  2018-09-13  ...     3.333                 NaN
# ...                       ...  ...       ...                 ...
# 18080870           2020-11-08  ...   116.667                 NaN
# 18080871           2020-11-08  ...   116.667                 NaN
# 18080872           2020-11-08  ...    28.000                 NaN
# 18080873           2020-11-08  ...    14.000                 NaN
# 18080874           2020-11-08  ...     5.000                 NaN
#
#           inpatient_caseID  inpatient_case_date_of_admission  \
# 0                      NaN                               NaN
# 1                      NaN                               NaN
# 2                      NaN                               NaN
# 3                      NaN                               NaN
# 4                      NaN                               NaN
# ...                    ...                               ...
# 18080870               NaN                               NaN
# 18080871               NaN                               NaN
# 18080872               NaN                               NaN
# 18080873               NaN                               NaN
# 18080874               NaN                               NaN
#
#           inpatient_case_date_of_discharge  inpatient_case_cause_of_admission  \
# 0                                      NaN                                NaN
# 1                                      NaN                                NaN
# 2                                      NaN                                NaN
# 3                                      NaN                                NaN
# 4                                      NaN                                NaN
# ...                                    ...                                ...
# 18080870                               NaN                                NaN
# 18080871                               NaN                                NaN
# 18080872                               NaN                                NaN
# 18080873                               NaN                                NaN
# 18080874                               NaN                                NaN
#
#          inpatient_case_cause_of_discharge  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 18080870                               NaN
# 18080871                               NaN
# 18080872                               NaN
# 18080873                               NaN
# 18080874                               NaN
#
#           inpatient_case_outpatient_treatment  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 18080870                                  NaN
# 18080871                                  NaN
# 18080872                                  NaN
# 18080873                                  NaN
# 18080874                                  NaN
#
#          inpatient_case_department_admission  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 18080870                                 NaN
# 18080871                                 NaN
# 18080872                                 NaN
# 18080873                                 NaN
# 18080874                                 NaN
#
#          inpatient_case_department_discharge
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 18080870                                 NaN
# 18080871                                 NaN
# 18080872                                 NaN
# 18080873                                 NaN
# 18080874                                 NaN
#
# [18080875 rows x 45 columns]

# %%
df_universal_8 = filter_by_timeframe(
    df_universal_8,
    insurance_from_col="insurance_from",
    insurance_to_col="insurance_to",
    case_from_col="inpatient_case_date_of_admission",
    case_to_col="inpatient_case_date_of_discharge"
)

df_universal_8
# Out:
#           pid  Year of birth  gender insurance_from insurance_to  death  \
# 7131        6           1979       1     2019-01-01   2019-12-18    0.0
# 7132        6           1979       1     2019-01-01   2019-12-18    0.0
# 7133        6           1979       1     2019-01-01   2019-12-18    0.0
# 7136        6           1979       1     2019-01-01   2019-12-18    0.0
# 7138        6           1979       1     2019-01-01   2019-12-18    0.0
# ...       ...            ...     ...            ...          ...    ...
# 18050319  987           1978       1     2019-01-01   2019-12-31    0.0
# 18050320  987           1978       1     2019-01-01   2019-12-31    0.0
# 18050321  987           1978       1     2019-01-01   2019-12-31    0.0
# 18050322  987           1978       1     2019-01-01   2019-12-31    0.0
# 18050323  987           1978       1     2019-01-01   2019-12-31    0.0
#
#           regional_code  outpatient_caseID  outpatient_case_practice_code  \
# 7131                8.0        205185163.0                    712978181.0
# 7132                8.0        205185163.0                    712978181.0
# 7133                8.0        205185163.0                    712978181.0
# 7136                8.0        205185163.0                    712978181.0
# 7138                8.0        205185163.0                    712978181.0
# ...                 ...                ...                            ...
# 18050319            5.0         94755127.0                    570365619.0
# 18050320            5.0         94755127.0                    570365619.0
# 18050321            5.0         94755127.0                    570365619.0
# 18050322            5.0         94755127.0                    570365619.0
# 18050323            5.0         94755127.0                    570365619.0
#
#          outpatient_case_from  ... drugs_ddd  inpatient_case_pid  \
# 7131               2019-04-10  ...    50.000                 6.0
# 7132               2019-04-10  ...    50.000                 6.0
# 7133               2019-04-10  ...    50.000                 6.0
# 7136               2019-04-10  ...    50.000                 6.0
# 7138               2019-04-10  ...    30.039                 6.0
# ...                       ...  ...       ...                 ...
# 18050319           2019-08-18  ...    50.000               987.0
# 18050320           2019-08-18  ...   200.000               987.0
# 18050321           2019-08-18  ...    30.039               987.0
# 18050322           2019-08-18  ...    30.039               987.0
# 18050323           2019-08-18  ...    30.039               987.0
#
#           inpatient_caseID  inpatient_case_date_of_admission  \
# 7131             5556089.0                        2019-06-14
# 7132             1568766.0                        2019-08-30
# 7133             2714453.0                        2019-03-30
# 7136            10361408.0                        2019-10-05
# 7138             5556089.0                        2019-06-14
# ...                    ...                               ...
# 18050319         6300871.0                        2019-01-10
# 18050320         6300871.0                        2019-01-10
# 18050321         6300871.0                        2019-01-10
# 18050322         6300871.0                        2019-01-10
# 18050323         6300871.0                        2019-01-10
#
#           inpatient_case_date_of_discharge  inpatient_case_cause_of_admission  \
# 7131                            2019-06-14                                NaN
# 7132                            2019-08-30                                NaN
# 7133                            2019-03-30                                NaN
# 7136                            2019-10-05                                NaN
# 7138                            2019-06-14                                NaN
# ...                                    ...                                ...
# 18050319                        2019-01-13                              101.0
# 18050320                        2019-01-13                              101.0
# 18050321                        2019-01-13                              101.0
# 18050322                        2019-01-13                              101.0
# 18050323                        2019-01-13                              101.0
#
#          inpatient_case_cause_of_discharge  \
# 7131                                   NaN
# 7132                                   NaN
# 7133                                   NaN
# 7136                                   NaN
# 7138                                   NaN
# ...                                    ...
# 18050319                               1.0
# 18050320                               1.0
# 18050321                               1.0
# 18050322                               1.0
# 18050323                               1.0
#
#           inpatient_case_outpatient_treatment  \
# 7131                                      1.0
# 7132                                      1.0
# 7133                                      1.0
# 7136                                      1.0
# 7138                                      1.0
# ...                                       ...
# 18050319                                  0.0
# 18050320                                  0.0
# 18050321                                  0.0
# 18050322                                  0.0
# 18050323                                  0.0
#
#          inpatient_case_department_admission  \
# 7131                                     NaN
# 7132                                     NaN
# 7133                                     NaN
# 7136                                     NaN
# 7138                                     NaN
# ...                                      ...
# 18050319                              3400.0
# 18050320                              3400.0
# 18050321                              3400.0
# 18050322                              3400.0
# 18050323                              3400.0
#
#          inpatient_case_department_discharge
# 7131                                     NaN
# 7132                                     NaN
# 7133                                     NaN
# 7136                                     NaN
# 7138                                     NaN
# ...                                      ...
# 18050319                              3400.0
# 18050320                              3400.0
# 18050321                              3400.0
# 18050322                              3400.0
# 18050323                              3400.0
#
# [4633303 rows x 45 columns]

# %%
df_inpatient_diagnosis = pd.read_csv('wig2/testdata/test.inpatient_diagnosis.csv', sep='\t')
df_inpatient_diagnosis = df_inpatient_diagnosis.add_prefix('inpatient_diagnosis_')
df_inpatient_diagnosis.columns = df_inpatient_diagnosis.columns.str.replace(' ', '_')
df_inpatient_diagnosis.rename(columns={"inpatient_diagnosis_pid": "pid", "inpatient_diagnosis_caseID": "inpatient_caseID"}, inplace=True)
df_inpatient_diagnosis
# Out:
#       pid  inpatient_caseID inpatient_diagnosis_diagnosis  \
# 0     227            104770                          Z019
# 1     225            111066                          M351
# 2     225            111066                          T887
# 3     225            111066                          R253
# 4     225            111066                          N028
# ...   ...               ...                           ...
# 1481  936          12095459                          M328
# 1482  936          12095459                          Z888
# 1483  936          12095459                          Z886
# 1484  936          12095459                          R768
# 1485  936          12095459                         M8580
#
#       inpatient_diagnosis_type_of_diagnosis  \
# 0                                         2
# 1                                         7
# 2                                         8
# 3                                         8
# 4                                         8
# ...                                     ...
# 1481                                      7
# 1482                                      8
# 1483                                      8
# 1484                                      8
# 1485                                      8
#
#       inpatient_diagnosis_is_main_diagnosis  inpatient_diagnosis_Localisation
# 0                                         1                               NaN
# 1                                         1                               NaN
# 2                                         0                               NaN
# 3                                         0                               NaN
# 4                                         0                               NaN
# ...                                     ...                               ...
# 1481                                      1                               NaN
# 1482                                      0                               NaN
# 1483                                      0                               NaN
# 1484                                      0                               NaN
# 1485                                      0                               NaN
#
# [1486 rows x 6 columns]

# %%
# 9 out of 11: insurance, insurance_data, outpatient_cases, outpatient_fees, outpatient_procedure, outpatient_diagnosis, drugs, inpatient_case, inpatient_diagnosis
df_universal_9 = pd.merge(df_universal_8, df_inpatient_diagnosis, on=['pid', 'inpatient_caseID'], how='left')
df_universal_9
# Out:
#          pid  Year of birth  gender insurance_from insurance_to  death  \
# 0          6           1979       1     2019-01-01   2019-12-18    0.0
# 1          6           1979       1     2019-01-01   2019-12-18    0.0
# 2          6           1979       1     2019-01-01   2019-12-18    0.0
# 3          6           1979       1     2019-01-01   2019-12-18    0.0
# 4          6           1979       1     2019-01-01   2019-12-18    0.0
# ...      ...            ...     ...            ...          ...    ...
# 7998468  987           1978       1     2019-01-01   2019-12-31    0.0
# 7998469  987           1978       1     2019-01-01   2019-12-31    0.0
# 7998470  987           1978       1     2019-01-01   2019-12-31    0.0
# 7998471  987           1978       1     2019-01-01   2019-12-31    0.0
# 7998472  987           1978       1     2019-01-01   2019-12-31    0.0
#
#          regional_code  outpatient_caseID  outpatient_case_practice_code  \
# 0                  8.0        205185163.0                    712978181.0
# 1                  8.0        205185163.0                    712978181.0
# 2                  8.0        205185163.0                    712978181.0
# 3                  8.0        205185163.0                    712978181.0
# 4                  8.0        205185163.0                    712978181.0
# ...                ...                ...                            ...
# 7998468            5.0         94755127.0                    570365619.0
# 7998469            5.0         94755127.0                    570365619.0
# 7998470            5.0         94755127.0                    570365619.0
# 7998471            5.0         94755127.0                    570365619.0
# 7998472            5.0         94755127.0                    570365619.0
#
#         outpatient_case_from  ... inpatient_case_date_of_discharge  \
# 0                 2019-04-10  ...                       2019-06-14
# 1                 2019-04-10  ...                       2019-08-30
# 2                 2019-04-10  ...                       2019-03-30
# 3                 2019-04-10  ...                       2019-10-05
# 4                 2019-04-10  ...                       2019-10-05
# ...                      ...  ...                              ...
# 7998468           2019-08-18  ...                       2019-01-13
# 7998469           2019-08-18  ...                       2019-01-13
# 7998470           2019-08-18  ...                       2019-01-13
# 7998471           2019-08-18  ...                       2019-01-13
# 7998472           2019-08-18  ...                       2019-01-13
#
#          inpatient_case_cause_of_admission  inpatient_case_cause_of_discharge  \
# 0                                      NaN                                NaN
# 1                                      NaN                                NaN
# 2                                      NaN                                NaN
# 3                                      NaN                                NaN
# 4                                      NaN                                NaN
# ...                                    ...                                ...
# 7998468                              101.0                                1.0
# 7998469                              101.0                                1.0
# 7998470                              101.0                                1.0
# 7998471                              101.0                                1.0
# 7998472                              101.0                                1.0
#
#          inpatient_case_outpatient_treatment  \
# 0                                        1.0
# 1                                        1.0
# 2                                        1.0
# 3                                        1.0
# 4                                        1.0
# ...                                      ...
# 7998468                                  0.0
# 7998469                                  0.0
# 7998470                                  0.0
# 7998471                                  0.0
# 7998472                                  0.0
#
#          inpatient_case_department_admission  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 7998468                               3400.0
# 7998469                               3400.0
# 7998470                               3400.0
# 7998471                               3400.0
# 7998472                               3400.0
#
#          inpatient_case_department_discharge inpatient_diagnosis_diagnosis  \
# 0                                        NaN                          Z019
# 1                                        NaN                          Z019
# 2                                        NaN                          Z019
# 3                                        NaN                          M328
# 4                                        NaN                           Z34
# ...                                      ...                           ...
# 7998468                               3400.0                          L932
# 7998469                               3400.0                          N390
# 7998470                               3400.0                          L932
# 7998471                               3400.0                          L932
# 7998472                               3400.0                          L718
#
#          inpatient_diagnosis_type_of_diagnosis  \
# 0                                            2
# 1                                            2
# 2                                            2
# 3                                            2
# 4                                            2
# ...                                        ...
# 7998468                                      7
# 7998469                                      8
# 7998470                                      4
# 7998471                                     11
# 7998472                                      8
#
#         inpatient_diagnosis_is_main_diagnosis inpatient_diagnosis_Localisation
# 0                                           1                              NaN
# 1                                           1                              NaN
# 2                                           1                              NaN
# 3                                           1                              NaN
# 4                                           0                              NaN
# ...                                       ...                              ...
# 7998468                                     1                              NaN
# 7998469                                     0                              NaN
# 7998470                                     0                              NaN
# 7998471                                     0                              NaN
# 7998472                                     0                              NaN
#
# [7998473 rows x 49 columns]

# %%
df_inpatient_fees = pd.read_csv('wig2/testdata/test.inpatient_fees.csv', sep='\t')
df_inpatient_fees = df_inpatient_fees.add_prefix('inpatient_fees_')
df_inpatient_fees.columns = df_inpatient_fees.columns.str.replace(' ', '_')
df_inpatient_fees.rename(columns={"inpatient_fees_pid": "pid", "inpatient_fees_caseID": "inpatient_caseID"}, inplace=True)
df_inpatient_fees
# Out:
#       pid  inpatient_caseID inpatient_fees_from inpatient_fees_to  \
# 0     542           1966155          2020-10-27        2020-10-27
# 1     867           6280672          2019-09-01        2019-09-01
# 2     867           6280672          2019-09-01        2019-09-01
# 3     987           6300871          2019-01-10        2019-01-12
# 4     987           6300871          2019-01-10        2019-01-12
# ...   ...               ...                 ...               ...
# 1341  343          11281843          2019-10-02        2019-10-02
# 1342  343          11281843          2019-10-02        2019-10-02
# 1343  343          11281843          2019-10-02        2019-10-02
# 1344  343          11281843          2019-10-02        2019-10-02
# 1345  343          11281843          2019-10-02        2019-10-02
#
#      inpatient_fees_billing_code  inpatient_fees_amount_due  \
# 0                       21000000                     299.99
# 1                       21000010                       4.55
# 2                       21000000                     103.30
# 3                       75105002                      84.14
# 4                       7010J61C                    2311.12
# ...                          ...                        ...
# 1341                    75105002                     136.66
# 1342                    7310Z64D                    -449.57
# 1343                    7010Z64D                    1321.87
# 1344                    49120001                      10.76
# 1345                    48000001                       1.30
#
#       inpatient_fees_quantity
# 0                         1.0
# 1                         1.0
# 2                         1.0
# 3                         1.0
# 4                         1.0
# ...                       ...
# 1341                      1.0
# 1342                      1.0
# 1343                      1.0
# 1344                      1.0
# 1345                      1.0
#
# [1346 rows x 7 columns]

# %%
# 10 out of 11: insurance, insurance_data, outpatient_cases, outpatient_fees, outpatient_procedure, outpatient_diagnosis, drugs, inpatient_case, inpatient_diagnosis, inpatient_fees
df_universal_10 = pd.merge(df_universal_9, df_inpatient_fees, on=['pid', 'inpatient_caseID'], how='left')
df_universal_10
# Out:
#           pid  Year of birth  gender insurance_from insurance_to  death  \
# 0           6           1979       1     2019-01-01   2019-12-18    0.0
# 1           6           1979       1     2019-01-01   2019-12-18    0.0
# 2           6           1979       1     2019-01-01   2019-12-18    0.0
# 3           6           1979       1     2019-01-01   2019-12-18    0.0
# 4           6           1979       1     2019-01-01   2019-12-18    0.0
# ...       ...            ...     ...            ...          ...    ...
# 18885522  987           1978       1     2019-01-01   2019-12-31    0.0
# 18885523  987           1978       1     2019-01-01   2019-12-31    0.0
# 18885524  987           1978       1     2019-01-01   2019-12-31    0.0
# 18885525  987           1978       1     2019-01-01   2019-12-31    0.0
# 18885526  987           1978       1     2019-01-01   2019-12-31    0.0
#
#           regional_code  outpatient_caseID  outpatient_case_practice_code  \
# 0                   8.0        205185163.0                    712978181.0
# 1                   8.0        205185163.0                    712978181.0
# 2                   8.0        205185163.0                    712978181.0
# 3                   8.0        205185163.0                    712978181.0
# 4                   8.0        205185163.0                    712978181.0
# ...                 ...                ...                            ...
# 18885522            5.0         94755127.0                    570365619.0
# 18885523            5.0         94755127.0                    570365619.0
# 18885524            5.0         94755127.0                    570365619.0
# 18885525            5.0         94755127.0                    570365619.0
# 18885526            5.0         94755127.0                    570365619.0
#
#          outpatient_case_from  ... inpatient_case_department_discharge  \
# 0                  2019-04-10  ...                                 NaN
# 1                  2019-04-10  ...                                 NaN
# 2                  2019-04-10  ...                                 NaN
# 3                  2019-04-10  ...                                 NaN
# 4                  2019-04-10  ...                                 NaN
# ...                       ...  ...                                 ...
# 18885522           2019-08-18  ...                              3400.0
# 18885523           2019-08-18  ...                              3400.0
# 18885524           2019-08-18  ...                              3400.0
# 18885525           2019-08-18  ...                              3400.0
# 18885526           2019-08-18  ...                              3400.0
#
#           inpatient_diagnosis_diagnosis  \
# 0                                  Z019
# 1                                  Z019
# 2                                  Z019
# 3                                  Z019
# 4                                  Z019
# ...                                 ...
# 18885522                           L718
# 18885523                           L718
# 18885524                           L718
# 18885525                           L718
# 18885526                           L718
#
#           inpatient_diagnosis_type_of_diagnosis  \
# 0                                             2
# 1                                             2
# 2                                             2
# 3                                             2
# 4                                             2
# ...                                         ...
# 18885522                                      8
# 18885523                                      8
# 18885524                                      8
# 18885525                                      8
# 18885526                                      8
#
#           inpatient_diagnosis_is_main_diagnosis  \
# 0                                             1
# 1                                             1
# 2                                             1
# 3                                             1
# 4                                             1
# ...                                         ...
# 18885522                                      0
# 18885523                                      0
# 18885524                                      0
# 18885525                                      0
# 18885526                                      0
#
#           inpatient_diagnosis_Localisation  inpatient_fees_from  \
# 0                                      NaN           2019-06-14
# 1                                      NaN           2019-06-14
# 2                                      NaN           2019-08-30
# 3                                      NaN           2019-08-30
# 4                                      NaN           2019-03-30
# ...                                    ...                  ...
# 18885522                               NaN           2019-01-10
# 18885523                               NaN           2019-01-10
# 18885524                               NaN           2019-01-10
# 18885525                               NaN           2019-01-10
# 18885526                               NaN           2019-01-10
#
#          inpatient_fees_to  inpatient_fees_billing_code  \
# 0               2019-06-14                     25101101
# 1               2019-06-14                     21000010
# 2               2019-08-30                     25101101
# 3               2019-08-30                     21000010
# 4               2019-03-30                     25101101
# ...                    ...                          ...
# 18885522        2019-01-12                     75105002
# 18885523        2019-01-12                     7010J61C
# 18885524        2019-01-12                     7010J61C
# 18885525        2019-01-12                     48000001
# 18885526        2019-01-12                     47200012
#
#          inpatient_fees_amount_due inpatient_fees_quantity
# 0                           203.29                     1.0
# 1                             4.72                     1.0
# 2                           203.29                     1.0
# 3                             4.72                     1.0
# 4                           203.29                     1.0
# ...                            ...                     ...
# 18885522                     84.14                     1.0
# 18885523                   2311.12                     1.0
# 18885524                  -1651.74                     1.0
# 18885525                      1.30                     1.0
# 18885526                    -11.32                     1.0
#
# [18885527 rows x 54 columns]

# %%
df_inpatient_procedures = pd.read_csv('wig2/testdata/test.inpatient_procedures.csv', sep='\t')
df_inpatient_procedures = df_inpatient_procedures.add_prefix('inpatient_procedures_')
df_inpatient_procedures.columns = df_inpatient_procedures.columns.str.replace(' ', '_')
df_inpatient_procedures.rename(columns={"inpatient_procedures_pid": "pid", "inpatient_procedures_caseID": "inpatient_caseID",
                                        "inpatient_procedures_date_of_procedure": "inpatient_date_of_procedure"}, inplace=True)
df_inpatient_procedures
# Out:
#      pid  inpatient_caseID inpatient_procedures_procedure_code  \
# 0    225            111066                               8-824
# 1    225            111066                               8-824
# 2    225            111066                            6-002.f3
# 3    233            174381                            8-810.w3
# 4    233            174381                               3-990
# ..   ...               ...                                 ...
# 339  619          11851394                             1-465.0
# 340  782          11962177                            8-542.11
# 341  936          12095459                            9-411.04
# 342  936          12095459                            9-410.05
# 343  936          12095459                               8-650
#
#      inpatient_procedures_localisation inpatient_date_of_procedure
# 0                                    9                  2018-01-27
# 1                                    9                  2018-01-28
# 2                                    9                  2018-01-26
# 3                                    9                  2019-01-19
# 4                                    9                  2019-01-20
# ..                                 ...                         ...
# 339                                  2                  2019-03-15
# 340                                  9                  2019-10-18
# 341                                  9                  2020-01-23
# 342                                  9                  2020-01-25
# 343                                  9                  2020-01-23
#
# [344 rows x 5 columns]

# %%
# 11 out of 11: insurance, insurance_data, outpatient_cases, outpatient_fees, outpatient_procedure, outpatient_diagnosis, drugs, inpatient_case, inpatient_diagnosis,
# inpatient_fees, inpatient_procedures
df_universal_11 = pd.merge(df_universal_10, df_inpatient_procedures, on=['pid', 'inpatient_caseID'], how='left')
df_universal_11
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df_drugs.loc[df_drugs['pid'] == 1]
# Out:
#       pid date of prescription date of dispense  pharma central number  \
# 2002    1           2020-12-13       2020-12-14                7387887
#
#       specialty of prescriber  physican code  practice code  quantity  \
# 2002                      1.0    999393101.0    793529553.0       1.0
#
#       amount due      atc    ddd
# 2002       12.42  N02BB02  3.333
